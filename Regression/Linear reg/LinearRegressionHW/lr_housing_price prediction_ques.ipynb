# %% [markdown]
# # 1. Problem Understanding
#
# We want to predict house prices using:
#
# Area Income
#
# House Age
#
# Number of Rooms
#
# Number of Bedrooms
#
# Area Population

# %% [markdown]
# # import basic libraries

# %% [markdown]
# # 2. load Dataset

# %% [markdown]
# # 3. EDA + Data Cleaning

# %% [markdown]
# ### basic plots

# %% [markdown]
# ### Histogram – Price Distribution

# %% [markdown]
# ### Scatter Plot – Income vs Price

# %% [markdown]
# ### Pairplot (Quick Relationship Overview)

# %% [markdown]
# ### Heatmap – Correlation Between Features

# %% [markdown]
# ### Box Plot – Price Outliers

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### drop address as it is not a important feature

# %% [markdown]
# ### seperate x and  y

# %% [markdown]
# # 5️. Train / Test Split

# %% [markdown]
# # 6. model Training

# %% [markdown]
# # 7. model Evaluation

# %% [markdown]
# ###  Visual Comparison

# %% [markdown]
# # 8. Hyperparameter Tuning
#
# We use Ridge Regression just like industry practice.

# %% [markdown]
# # 9. Final Model Training

# %% [markdown]
# # 10. Save Model
